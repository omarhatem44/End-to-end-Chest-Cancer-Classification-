# %%
d = {"key":"value","key1" : "value1" }

# %%
d["key"]
# Out:
# 'value'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox
d2 = {"key":"value","key1": "value1"}
d2 = ConfigBox(d2)
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key1
# Out:
# 'value1'

# %%
def get_product(x:int, y:int):
    return x*y
get_product(x = 2, y = 3)
# Out:
# 6

# %%
get_product(x = 2, y = "3")
# Out:
# '33'

# %%
from ensure import ensure_annotations
@ensure_annotations
def get_product(x:int, y:int):
    return x*y

get_product(x = 2, y = 3)
# Out:
# 6

# %%
get_product(x = 2, y = "3")

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1OuHWGqwU5za4Fr5bpWpnniUE8XtFAF2C/view?usp=drive_link"
file_id = url.split("/")[-2]
file_id
# Out:
# '1OuHWGqwU5za4Fr5bpWpnniUE8XtFAF2C'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1OuHWGqwU5za4Fr5bpWpnniUE8XtFAF2C
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1OuHWGqwU5za4Fr5bpWpnniUE8XtFAF2C&confirm=t&uuid=c3c90479-4fa8-4283-ae22-1bb972a82007
# To: d:\omar\MLOps\Chest-Cancer-Classification\research\Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:28<00:00, 1.75MB/s]
# 'Chest-CT-Scan-data.zip'
